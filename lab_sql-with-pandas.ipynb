# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Practice SQL with Pandas pt. 2
#
#
# ---
#
# We've learned about relational databases and the language most use to query them, SQL.
#
# In this lab we are going to gain more practice converting information to a SQL DB, querying the data and then analyzing it with Python.

# %%
# Necessary Libraries
import pandas as pd
import sqlite3
from pandas.io import sql

# %% [markdown]
# #### 1.  Read in the EuroMart CSV Data.
# - 'EuroMart-ListOfOrders.csv'
# - 'EuroMart-OrderBreakdown.csv'
# - 'EuroMart-SalesTargets.csv'

# %%
# Reading CSV to Dataframe
orders = pd.read_csv('./datasets/csv/EuroMart-ListOfOrders.csv', encoding = 'utf-8')
OBD =  pd.read_csv('./datasets/csv/EuroMart-OrderBreakdown.csv', encoding = 'utf-8')
sales_targets =  pd.read_csv('./datasets/csv/EuroMart-SalesTargets.csv', encoding = 'utf-8')

# %%
orders.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039   1/1/2011        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313   1/3/2011    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300   1/4/2011  Devin Huddleston     Valence          France
# 3  BN-2011-2819714   1/4/2011       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423   1/5/2011      Daniel Burke  Echirolles          France
#
#     Region      Segment Ship Date     Ship Mode                 State
# 0    North  Home Office  1/5/2011  Economy Plus             Stockholm
# 1    North     Consumer  1/7/2011       Economy               England
# 2  Central     Consumer  1/8/2011       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate  1/9/2011       Economy               England
# 4  Central  Home Office  1/7/2011      Priority  Auvergne-Rhône-Alpes

# %%
OBD.head()
# Out:
#           Order ID                           Product Name  Discount    Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5   $45.00
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0  $854.00
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0  $140.00
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5   $27.00
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5   $17.00
#
#     Profit  Quantity         Category Sub-Category
# 0  -$26.00         3  Office Supplies        Paper
# 1  $290.00         7        Furniture    Bookcases
# 2   $21.00         3  Office Supplies          Art
# 3  -$22.00         2  Office Supplies          Art
# 4   -$1.00         2  Office Supplies      Storage

# %%
sales_targets.head()
# Out:
#   Month of Order Date   Category      Target
# 0              Jan-11  Furniture  $10,000.00
# 1              Feb-11  Furniture  $10,100.00
# 2              Mar-11  Furniture  $10,300.00
# 3              Apr-11  Furniture  $10,400.00
# 4              May-11  Furniture  $10,500.00

# %% [markdown]
# #### 2. Rename columns to remove any spaces.

# %%
# Rename columns in orders dataframe
orders = orders.rename(columns={'Order ID': 'OrderID', 'Order Date': 'OrderDate', 'Customer Name': 'CustomerName', \
                      'Ship Date': 'ShipDate', 'Ship Mode': 'ShipMode'})
orders.head(1)
# Out:
#            OrderID OrderDate CustomerName       City Country Region  \
# 0  BN-2011-7407039  1/1/2011   Ruby Patel  Stockholm  Sweden  North
#
#        Segment  ShipDate      ShipMode      State
# 0  Home Office  1/5/2011  Economy Plus  Stockholm

# %%
# Rename columns in OBD dataframe
OBD = OBD.rename(columns={'Order ID': 'OrderID', 'Product Name': 'ProductName'})
OBD.head(1)
# Out:
#            OrderID                  ProductName  Discount   Sales   Profit  \
# 0  BN-2011-7407039  Enermax Note Cards, Premium       0.5  $45.00  -$26.00
#
#    Quantity         Category Sub-Category
# 0         3  Office Supplies        Paper

# %%
# Rename columns in sales_targets dataframe
sales_targets = sales_targets.rename(columns={'Month of Order Date': 'MonthOfOrderDate'})
sales_targets.head(1)
# Out:
#   MonthOfOrderDate   Category      Target
# 0           Jan-11  Furniture  $10,000.00

# %% [markdown]
# #### 3. Remove dollar signs from sales and profit columns in the order breakdown dataframe.
#
# Convert the columns to float.

# %%
OBD.dtypes
# Out:
# OrderID          object
# ProductName      object
# Discount        float64
# Sales            object
# Profit           object
# Quantity          int64
# Category         object
# Sub-Category     object
# dtype: object

# %%
OBD['Sales'] = OBD['Sales'].map(lambda x: x.strip('$'))
OBD['Sales'] = OBD['Sales'].map(lambda x: float(x.replace(',','')))

OBD['Profit'] = OBD['Profit'].map(lambda x: x.replace('$',''))
OBD['Profit'] = OBD['Profit'].map(lambda x: float(x.replace(',','')))

OBD.dtypes
# Out:
# OrderID          object
# ProductName      object
# Discount        float64
# Sales           float64
# Profit          float64
# Quantity          int64
# Category         object
# Sub-Category     object
# dtype: object

# %% [markdown]
# #### 4. Create a SQL Database called 'EuroMart' and save the three dataframes as SQL tables.

# %%
# Establishing Local DB connection
db_connection = sqlite3.connect('./datasets/sql/EuroMart.db.sqlite')

# %%
# Convert dataframes into SQL databases
orders.to_sql(name='orders', con=db_connection, if_exists='replace', index=False)
OBD.to_sql(name='OBD', con=db_connection, if_exists='replace', index=False)
sales_targets.to_sql(name='sales_targets', con=db_connection, if_exists='replace', index=False)

# %% [markdown]
# #### 5. How many orders has each Customer placed?

# %%
sql.read_sql('SELECT CustomerName, \
COUNT(*) AS Total \
FROM orders \
GROUP BY CustomerName \
ORDER BY Total DESC', con=db_connection)
# Out:
#             CustomerName  Total
# 0           Jose Gambino     13
# 1           Kayla Tearle     12
# 2        Mark Washington     12
# 3          Aaron Bootman     11
# 4        Georgina Garner     11
# 5         Hayden Perkins     11
# 6            Jason Roger     11
# 7        Jessica Paramor     11
# 8         Lilly Le Grand     11
# 9            Lori Miller     11
# 10        Maya Pamphlett     11
# 11         Michael Myers     11
# 12        Patricia Smith     11
# 13          Rachel Tyler     11
# 14         Terence Welch     11
# 15   Alexandra Macdonald     10
# 16      Angie Massengill     10
# 17        Ashton Charles     10
# 18     Chelsea Bannister     10
# 19        Elijah Sodeman     10
# 20             Elise Ali     10
# 21          Eloise Sykes     10
# 22           Isaac David     10
# 23        Jasmine Slater     10
# 24         Katie Evenden     10
# 25            Kian Sykes     10
# 26       Michael Watkins     10
# 27           Ngoc Orozco     10
# 28           Owen Howell     10
# 29            Peter Daly     10
# ..                   ...    ...
# 762    Alexandra Mahmood      1
# 763          Anna Church      1
# 764      Audrey Prentice      1
# 765          Audry Smith      1
# 766      Bella Handfield      1
# 767       Bethany Powell      1
# 768         Charles Rice      1
# 769         Claire Dilke      1
# 770   Clifford Defreitas      1
# 771        Dakota Baynes      1
# 772        Dustin Thomas      1
# 773          Elliot Owen      1
# 774          Erin Wallis      1
# 775          Grace Brown      1
# 776        Hayden Weigel      1
# 777      Herbert Harrell      1
# 778      Imogen Smithies      1
# 779         Jack Maughan      1
# 780          James Brown      1
# 781          Jay Collier      1
# 782         Jodie Garner      1
# 783         Louie Bryant      1
# 784         Mason Porter      1
# 785            Max Baker      1
# 786     Patrick Atkinson      1
# 787        Pearl Summers      1
# 788         Shannon Lane      1
# 789       Stephanie Ewen      1
# 790         Tegan Savage      1
# 791      Tyler Whitehead      1
#
# [792 rows x 2 columns]

# %% [markdown]
# > *If you're doubting your output check using Pandas*

# %%
# Get customer names
customers = sql.read_sql('SELECT CustomerName FROM orders', con=db_connection)

# Count values in list
customers['CustomerName'].value_counts()
# Out:
# Jose Gambino           13
# Kayla Tearle           12
# Mark Washington        12
# Georgina Garner        11
# Hayden Perkins         11
# Lori Miller            11
# Lilly Le Grand         11
# Jessica Paramor        11
# Jason Roger            11
# Rachel Tyler           11
# Michael Myers          11
# Patricia Smith         11
# Maya Pamphlett         11
# Aaron Bootman          11
# Terence Welch          11
# Michael Watkins        10
# Ngoc Orozco            10
# Rory Jess              10
# Philip Newsom          10
# Chelsea Bannister      10
# Jasmine Slater         10
# Elise Ali              10
# Robert Quick           10
# Angie Massengill       10
# Elijah Sodeman         10
# Eloise Sykes           10
# Katie Evenden          10
# Kian Sykes             10
# Peter Daly             10
# Alexandra Macdonald    10
#                        ..
# Jay Collier             1
# Erin Wallis             1
# Grace Brown             1
# Alexandra Mahmood       1
# James Brown             1
# Imogen Smithies         1
# Claire Dilke            1
# Patrick Atkinson        1
# Herbert Harrell         1
# Tyler Whitehead         1
# Louie Bryant            1
# Audrey Prentice         1
# Bella Handfield         1
# Bethany Powell          1
# Elliot Owen             1
# Dakota Baynes           1
# Jack Maughan            1
# Mason Porter            1
# Clifford Defreitas      1
# Hayden Weigel           1
# Charles Rice            1
# Pearl Summers           1
# Tegan Savage            1
# Audry Smith             1
# Jodie Garner            1
# Aaron Macrossan         1
# Anna Church             1
# Shannon Lane            1
# Max Baker               1
# Dustin Thomas           1
# Name: CustomerName, Length: 792, dtype: int64

# %% [markdown]
# #### 6. Create a Query to return a table of only geographic features from the List of Orders Table.

# %%
sql.read_sql('SELECT City, Country, Region, State FROM orders', con=db_connection)
# Out:
#                      City         Country   Region  \
# 0               Stockholm          Sweden    North
# 1               Southport  United Kingdom    North
# 2                 Valence          France  Central
# 3              Birmingham  United Kingdom    North
# 4              Echirolles          France  Central
# 5        La Seyne-sur-Mer          France  Central
# 6                Toulouse          France  Central
# 7                   Genoa           Italy    South
# 8                  Vienna         Austria  Central
# 9                  Murcia           Spain    South
# 10                 Woking  United Kingdom    North
# 11                  Lohne         Germany  Central
# 12              Leicester  United Kingdom    North
# 13              Sheffield  United Kingdom    North
# 14              Dordrecht     Netherlands  Central
# 15             Gothenburg          Sweden    North
# 16                 Vienna         Austria  Central
# 17                 Langen         Germany  Central
# 18             Copenhagen         Denmark    North
# 19                 Gandia           Spain    South
# 20                Esbjerg         Denmark    North
# 21     Sesto San Giovanni           Italy    South
# 22                Trapani           Italy    South
# 23     Villiers-sur-Marne          France  Central
# 24              Bielefeld         Germany  Central
# 25                 Leuven         Belgium  Central
# 26                  Prato           Italy    South
# 27                   Gela           Italy    South
# 28                Bologna           Italy    South
# 29                 Menden         Germany  Central
# ...                   ...             ...      ...
# 4087                 Linz         Austria  Central
# 4088               Lisbon        Portugal    South
# 4089              Ferrara           Italy    South
# 4090             Schwerin         Germany  Central
# 4091            Stockholm          Sweden    North
# 4092               Harrow  United Kingdom    North
# 4093                Milan           Italy    South
# 4094            Stockholm          Sweden    North
# 4095            The Hague     Netherlands  Central
# 4096        Wolverhampton  United Kingdom    North
# 4097               London  United Kingdom    North
# 4098  Champigny-sur-Marne          France  Central
# 4099             Pamplona           Spain    South
# 4100              Oyonnax          France  Central
# 4101            Sarcelles          France  Central
# 4102              Haarlem     Netherlands  Central
# 4103            Stockholm          Sweden    North
# 4104               Dublin         Ireland    North
# 4105             Plymouth  United Kingdom    North
# 4106               Munich         Germany  Central
# 4107            Edinburgh  United Kingdom    North
# 4108               Naples           Italy    South
# 4109                Basel     Switzerland  Central
# 4110            The Hague     Netherlands  Central
# 4111                 Caen          France  Central
# 4112            Bielefeld         Germany  Central
# 4113           Maidenhead  United Kingdom    North
# 4114            Worcester  United Kingdom    North
# 4115              Hamburg         Germany  Central
# 4116            Eindhoven     Netherlands  Central
#
#                                    State
# 0                              Stockholm
# 1                                England
# 2                   Auvergne-Rhône-Alpes
# 3                                England
# 4                   Auvergne-Rhône-Alpes
# 5             Provence-Alpes-Côte d'Azur
# 6     Languedoc-Roussillon-Midi-Pyrénées
# 7                                Liguria
# 8                                 Vienna
# 9                                 Murcia
# 10                               England
# 11                          Lower Saxony
# 12                               England
# 13                               England
# 14                         South Holland
# 15                       Västra Götaland
# 16                                Vienna
# 17                          Lower Saxony
# 18                           Hovedstaden
# 19                            Valenciana
# 20                         South Denmark
# 21                              Lombardy
# 22                                Sicily
# 23                         Ile-de-France
# 24                North Rhine-Westphalia
# 25                       Flemish Brabant
# 26                               Tuscany
# 27                                Sicily
# 28                        Emilia-Romagna
# 29                North Rhine-Westphalia
# ...                                  ...
# 4087                       Upper Austria
# 4088                              Lisboa
# 4089                      Emilia-Romagna
# 4090              Mecklenburg-Vorpommern
# 4091                           Stockholm
# 4092                             England
# 4093                            Lombardy
# 4094                           Stockholm
# 4095                       South Holland
# 4096                             England
# 4097                             England
# 4098                       Ile-de-France
# 4099                             Navarra
# 4100                Auvergne-Rhône-Alpes
# 4101                       Ile-de-France
# 4102                       North Holland
# 4103                           Stockholm
# 4104                              Dublin
# 4105                             England
# 4106                             Bavaria
# 4107                            Scotland
# 4108                            Campania
# 4109                         Basel-Stadt
# 4110                       South Holland
# 4111                            Normandy
# 4112              North Rhine-Westphalia
# 4113                             England
# 4114                             England
# 4115                             Hamburg
# 4116                       North Brabant
#
# [4117 rows x 4 columns]

# %% [markdown]
# #### 7. Create a Query to return a table with all of the orders that had a negative profit from the Order Breakdown Table.

# %%
sql.read_sql('SELECT * FROM OBD WHERE Profit < 0', con=db_connection).head()
# Out:
#            OrderID                      ProductName  Discount  Sales  Profit  \
# 0  BN-2011-7407039      Enermax Note Cards, Premium       0.5   45.0   -26.0
# 1  BN-2011-2819714       Boston Markers, Easy-Erase       0.5   27.0   -22.0
# 2  BN-2011-2819714      Eldon Folders, Single Width       0.5   17.0    -1.0
# 3  BN-2011-3248724     Ikea Classic Bookcase, Metal       0.6  987.0 -1012.0
# 4  BN-2011-3248724  Binney & Smith Sketch Pad, Blue       0.5  116.0   -56.0
#
#    Quantity         Category Sub-Category
# 0         3  Office Supplies        Paper
# 1         2  Office Supplies          Art
# 2         2  Office Supplies      Storage
# 3         6        Furniture    Bookcases
# 4         5  Office Supplies          Art

# %% [markdown]
# #### 8. Construct a query to return a table with the Customer Name and Product Name.
#
# > **Note:** This will require a join!

# %%
sql.read_sql('SELECT orders."OrderID", orders."CustomerName", OBD."ProductName" \
FROM orders \
INNER JOIN OBD \
ON orders."OrderID" = OBD."OrderID"', con=db_connection)
# Out:
#               OrderID         CustomerName  \
# 0     BN-2011-7407039           Ruby Patel
# 1     AZ-2011-9050313       Summer Hayward
# 2     AZ-2011-6674300     Devin Huddleston
# 3     BN-2011-2819714          Mary Parker
# 4     BN-2011-2819714          Mary Parker
# 5      AZ-2011-617423         Daniel Burke
# 6      AZ-2011-617423         Daniel Burke
# 7     AZ-2011-2918397   Fredrick Beveridge
# 8     AZ-2011-2918397   Fredrick Beveridge
# 9     AZ-2011-2918397   Fredrick Beveridge
# 10    BN-2011-3248724          Archer Hort
# 11    BN-2011-3248724          Archer Hort
# 12    AZ-2011-6712797       Evie Flockhart
# 13    AZ-2011-4827146      Faith Greenwood
# 14    AZ-2011-4827146      Faith Greenwood
# 15    AZ-2011-6439906       Summer Hayward
# 16    AZ-2011-6439906       Summer Hayward
# 17    AZ-2011-7053593        Gracie Powell
# 18    AZ-2011-7053593        Gracie Powell
# 19    AZ-2011-5702370       Hershel Snyder
# 20    AZ-2011-5702370       Hershel Snyder
# 21    AZ-2011-5702370       Hershel Snyder
# 22    AZ-2011-5702370       Hershel Snyder
# 23    AZ-2011-9927716        Julia Martell
# 24    AZ-2011-2222024         Viola Watson
# 25    BN-2011-4913858         Julian Dobie
# 26    BN-2011-4913858         Julian Dobie
# 27    BN-2011-4913858         Julian Dobie
# 28    BN-2011-4913858         Julian Dobie
# 29    BN-2011-2807470            Rose Heap
# ...               ...                  ...
# 8017  AZ-2014-6752912      Lauren Saunders
# 8018  AZ-2014-6752912      Lauren Saunders
# 8019  AZ-2014-6752912      Lauren Saunders
# 8020  AZ-2014-8026360        Darcy Farnell
# 8021  AZ-2014-8026360        Darcy Farnell
# 8022  AZ-2014-8026360        Darcy Farnell
# 8023  BN-2014-5301206          Jay Collier
# 8024  BN-2014-4912801        Rachel Morton
# 8025  BN-2014-4912801        Rachel Morton
# 8026  BN-2014-3913645      Mark Washington
# 8027  BN-2014-3913645      Mark Washington
# 8028  BN-2014-3913645      Mark Washington
# 8029  AZ-2014-8007090       Mary Saterfiel
# 8030  AZ-2014-5047236    Alexis O'Flaherty
# 8031   AZ-2014-157670           Max Ludwig
# 8032   AZ-2014-436448     Georgia Arundale
# 8033  AZ-2014-3870231      Thomas Thompson
# 8034  AZ-2014-3870231      Thomas Thompson
# 8035  AZ-2014-3870231      Thomas Thompson
# 8036  AZ-2014-3870231      Thomas Thompson
# 8037  BN-2014-8679573       Dennis Conaway
# 8038  AZ-2014-4217323          Evie Morton
# 8039  AZ-2014-8174835         Eloise Sykes
# 8040   AZ-2014-766953         Jose Gambino
# 8041   AZ-2014-766953         Jose Gambino
# 8042  AZ-2014-1412225          Leon Barnes
# 8043  AZ-2014-7604524  Rebecca Chamberlain
# 8044  BN-2014-4140795      Daniel Hamilton
# 8045  BN-2014-4140795      Daniel Hamilton
# 8046  BN-2014-4140795      Daniel Hamilton
#
#                                             ProductName
# 0                           Enermax Note Cards, Premium
# 1                    Dania Corner Shelving, Traditional
# 2                 Binney & Smith Sketch Pad, Easy-Erase
# 3                            Boston Markers, Easy-Erase
# 4                           Eldon Folders, Single Width
# 5          Binney & Smith Pencil Sharpener, Water Color
# 6                           Sanford Canvas, Fluorescent
# 7                     Accos Thumb Tacks, Assorted Sizes
# 8                         Bush Floating Shelf Set, Pine
# 9                             Smead Lockers, Industrial
# 10                      Binney & Smith Sketch Pad, Blue
# 11                         Ikea Classic Bookcase, Metal
# 12                  Ibico Hole Reinforcements, Recycled
# 13                           Boston Canvas, Fluorescent
# 14                            Smead Trays, Single Width
# 15            Bevis Training Table, with Bottom Storage
# 16             Novimex File Folder Labels, Alphabetical
# 17                          Binney & Smith Canvas, Blue
# 18                SAFCO Executive Leather Armchair, Red
# 19                          Binney & Smith Canvas, Blue
# 20                                 Epson Printer, White
# 21                               Ibico Index Tab, Clear
# 22                 Ikea Stackable Bookrack, Traditional
# 23                             Hon Chairmat, Adjustable
# 24                     Green Bar Note Cards, Multicolor
# 25              Green Bar Cards & Envelopes, Multicolor
# 26    Harbour Creations Legal Exhibit Labels, Laser ...
# 27                                  Smead Lockers, Blue
# 28            Wilson Jones Hole Reinforcements, Durable
# 29                            Sanford Pens, Fluorescent
# ...                                                 ...
# 8017                     Lesro Round Table, Rectangular
# 8018            Motorola Signal Booster, with Caller ID
# 8019                Xerox Cards & Envelopes, Multicolor
# 8020                           Deflect-O Clock, Durable
# 8021                             Epson Inkjet, Wireless
# 8022                    Panasonic Card Printer, Durable
# 8023                       Novimex Rocking Chair, Black
# 8024                              BIC Pens, Fluorescent
# 8025                         Sanford Highlighters, Blue
# 8026                        Avery 3-Hole Punch, Economy
# 8027                                   Sharp Ink, Laser
# 8028                               Stanley Canvas, Blue
# 8029                         Fellowes Box, Single Width
# 8030                    Rubbermaid Door Stop, Erganomic
# 8031                   Office Star Chairmat, Adjustable
# 8032                               Acco Binder, Economy
# 8033                        Canon Fax and Copier, Laser
# 8034                          Kleencut Ruler, Easy Grip
# 8035                      Nokia Headset, with Caller ID
# 8036                               Sanford Canvas, Blue
# 8037                          Cuisinart Blender, Silver
# 8038                       Fellowes Lockers, Wire Frame
# 8039                          Kleencut Shears, Serrated
# 8040               Ikea Stackable Bookrack, Traditional
# 8041                          Motorola Audio Dock, VoIP
# 8042                    Fellowes Shelving, Single Width
# 8043                    Wilson Jones Index Tab, Economy
# 8044                      Avery Binder Covers, Recycled
# 8045                  BIC Pencil Sharpener, Fluorescent
# 8046                                StarTech Phone, Red
#
# [8047 rows x 3 columns]

# %% [markdown]
# #### 9.  How many orders for "Office Supplies" (Category) has Sweden made?
#
# > **Note:** from this point on you'll probably be combining SQL and Pandas, in that you would use SQL querys to gather the relevant information and use Pandas to analyze it.

# %%
sweden_offsupp = sql.read_sql('SELECT orders."OrderID", orders."Country", OBD."Category" \
FROM orders \
LEFT JOIN OBD \
ON orders."OrderID" = OBD."OrderID" \
WHERE orders."Country" = "Sweden" and OBD."Category" = "Office Supplies"', con=db_connection)

sweden_offsupp.count()
# Out:
# OrderID     133
# Country     133
# Category    133
# dtype: int64

# %% [markdown]
# #### 10. What was the total sales for products that have been discounted?

# %%
sales_disc = sql.read_sql('SELECT Discount, Sales FROM OBD WHERE Discount > 0', con=db_connection)
sales_disc['Sales'].sum()
# Out:
# 1115614.0

# %% [markdown]
# #### 11. What is the total quantity of objects sold for each country?

# %%
quant_country = sql.read_sql('SELECT OBD."Quantity", orders."Country" \
FROM orders \
INNER JOIN OBD \
ON OBD."OrderID" = orders."OrderID"', con=db_connection)

quant_country.groupby('Country').sum()
# Out:
#                 Quantity
# Country
# Austria              973
# Belgium              532
# Denmark              204
# Finland              201
# France              7329
# Germany             6179
# Ireland              392
# Italy               3612
# Netherlands         1526
# Norway               261
# Portugal             286
# Spain               2881
# Sweden               753
# Switzerland          308
# United Kingdom      4917

# %% [markdown]
# #### 12. In what Countries are profits lowest? (Report lowest 5-10)

# %%
profits = sql.read_sql('SELECT orders."Country", OBD."Profit" \
FROM orders \
INNER JOIN OBD \
ON OBD."OrderID" = orders."OrderID"', con=db_connection)

profits.groupby('Country').sum().sort_values('Profit').reset_index()[5:11]
# Out:
#         Country   Profit
# 5       Finland   3908.0
# 6        Norway   5167.0
# 7   Switzerland   7234.0
# 8       Belgium   9912.0
# 9         Italy  15802.0
# 10      Austria  21332.0

# %% [markdown]
# #### 13. What Counties have the best and worst Sales to Profit Ratios?
# (Total Sales divided by Total Profits.)
# Essentially this is saying for every dollar of product sold, how much is profit.

# %%
sp_ratio = sql.read_sql('SElECT orders."Country", OBD."Sales", OBD."Profit" \
FROM orders \
INNER JOIN OBD \
ON OBD."OrderID" = orders."OrderID"', con=db_connection) 

sp_ratio2 = sp_ratio.groupby('Country').sum().sort_values('Profit')

sp_ratio2['SalesProfitRatio'] = sp_ratio2['Profit'] / sp_ratio2['Sales']

sp_ratio2.sort_values('SalesProfitRatio', ascending=False)

# Switzerland has the best, Portugal has the worst
# Out:
#                    Sales   Profit  SalesProfitRatio
# Country
# Switzerland      24874.0   7234.0          0.290826
# Austria          79382.0  21332.0          0.268726
# Norway           20529.0   5167.0          0.251693
# Belgium          42320.0   9912.0          0.234216
# United Kingdom  420497.0  90382.0          0.214941
# Finland          20702.0   3908.0          0.188774
# Spain           249402.0  47067.0          0.188719
# Germany         488681.0  86279.0          0.176555
# France          609683.0  70067.0          0.114924
# Italy           252742.0  15802.0          0.062522
# Ireland          15998.0  -6886.0         -0.430429
# Denmark           7763.0  -3608.0         -0.464769
# Netherlands      70313.0 -37188.0         -0.528892
# Sweden           30490.0 -17524.0         -0.574746
# Portugal         15106.0  -8704.0         -0.576195

# %% [markdown]
# #### 14. What Shipping method is most common for 'Bookcases' (Sub Category)?

# %%
sql.read_sql('SELECT orders."ShipMode", OBD."Sub-Category" \
FROM orders \
INNER JOIN OBD \
ON OBD."OrderID" = orders."OrderID" \
WHERE OBD."Sub-Category" = "Bookcases"', con=db_connection)['ShipMode'].value_counts()

# Economy
# Out:
# Economy         234
# Economy Plus     76
# Priority         59
# Immediate        22
# Name: ShipMode, dtype: int64

# %% [markdown]
# #### 15 .What city in the Orders table generated the highest net sales?  (List all the cities and countries in descending order by net sales.)

# %%
sql.read_sql('SELECT orders."City", orders."Country", OBD."Sales" \
FROM orders \
INNER JOIN OBD \
ON orders."OrderID" = OBD."OrderID"', \
             con=db_connection).groupby(['City', 'Country']).sum().sort_values('Sales', ascending=False)

# London, UK
# Out:
#                                           Sales
# City                    Country
# London                  United Kingdom  69230.0
# Berlin                  Germany         52555.0
# Vienna                  Austria         51844.0
# Madrid                  Spain           44981.0
# Paris                   France          42245.0
# Rome                    Italy           28330.0
# Barcelona               Spain           27405.0
# Hamburg                 Germany         23574.0
# Marseille               France          21677.0
# Turin                   Italy           19829.0
# Milan                   Italy           18837.0
# Munich                  Germany         18429.0
# Edinburgh               United Kingdom  18016.0
# Stockholm               Sweden          17498.0
# Bremen                  Germany         15342.0
# Bochum                  Germany         15144.0
# Valencia                Spain           14958.0
# Frankfurt               Germany         14640.0
# Lille                   France          14102.0
# Cologne                 Germany         13301.0
# Nice                    France          13229.0
# Dortmund                Germany         12724.0
# Leipzig                 Germany         12380.0
# Leeds                   United Kingdom  11884.0
# Toulouse                France          11565.0
# Krefeld                 Germany         11410.0
# Naples                  Italy           11388.0
# Essen                   Germany         11211.0
# Dublin                  Ireland         11071.0
# Valladolid              Spain           10938.0
# ...                                         ...
# Montigny-le-Bretonneux  France             36.0
# Lagny-sur-Marne         France             35.0
# Randers                 Denmark            34.0
# Estepona                Spain              34.0
# Torremolinos            Spain              33.0
# Saint-Jean-de-la-Ruelle France             31.0
# La Crau                 France             31.0
# Castellammare di Stabia Italy              30.0
# Odivelas                Portugal           29.0
# Cluses                  France             28.0
# Vigevano                Italy              28.0
# Oss                     Netherlands        27.0
# Morley                  United Kingdom     27.0
# Givors                  France             26.0
# Massa                   Italy              26.0
# Falconara Marittima     Italy              26.0
# Viroflay                France             26.0
# Andria                  Italy              26.0
# Manfredonia             Italy              25.0
# Illkirch-Graffenstaden  France             24.0
# Cestas                  France             23.0
# Ragusa                  Italy              22.0
# Battipaglia             Italy              22.0
# Millau                  France             21.0
# Leiden                  Netherlands        19.0
# Friedberg               Germany            18.0
# Sorgues                 France             14.0
# Sète                    France             14.0
# Aix-les-Bains           France             10.0
# Osny                    France              5.0
#
# [999 rows x 1 columns]

# %% [markdown]
# #### BONUS: Create a Column called 'Shipping Delay' on the 'orders' table, which is the difference in days between 'Order Date' and 'Ship Date'.

# %%
# Check datatypes
orders.dtypes
# Out:
# OrderID         object
# OrderDate       object
# CustomerName    object
# City            object
# Country         object
# Region          object
# Segment         object
# ShipDate        object
# ShipMode        object
# State           object
# dtype: object

# %%
# Convert datatype from string to datetime
orders['OrderDate'] = pd.to_datetime(orders['OrderDate'])
orders['ShipDate'] = pd.to_datetime(orders['ShipDate'])

# %%
# Re-check datatypes to confirm the conversion worked
orders.dtypes
# Out:
# OrderID                 object
# OrderDate       datetime64[ns]
# CustomerName            object
# City                    object
# Country                 object
# Region                  object
# Segment                 object
# ShipDate        datetime64[ns]
# ShipMode                object
# State                   object
# dtype: object

# %%
orders['ShippingDelay'] = (orders['ShipDate'] - orders['OrderDate']).astype('timedelta64[D]')
orders.head()
# Out:
#            OrderID  OrderDate      CustomerName        City         Country  \
# 0  BN-2011-7407039 2011-01-01        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313 2011-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2011-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2011-01-04       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423 2011-01-05      Daniel Burke  Echirolles          France
#
#     Region      Segment   ShipDate      ShipMode                 State  \
# 0    North  Home Office 2011-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2011-01-07       Economy               England
# 2  Central     Consumer 2011-01-08       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate 2011-01-09       Economy               England
# 4  Central  Home Office 2011-01-07      Priority  Auvergne-Rhône-Alpes
#
#    ShippingDelay
# 0            4.0
# 1            4.0
# 2            4.0
# 3            5.0
# 4            2.0

# %% [markdown]
# #### BONUS: Update your Orders table in your Sqlite DB to include the 'Shipping Delay' feature.

# %%
orders.to_sql(name='orders', con=db_connection, if_exists='replace', index=False)

# %% [markdown]
# #### BONUS: Which Product Category has the highest average 'Shipping Delay'?

# %%
sql.read_sql('SELECT OBD."Category", orders."ShippingDelay" \
FROM OBD \
INNER JOIN orders \
ON orders."OrderID" = OBD."OrderID" \
', con=db_connection).groupby('Category').mean()
# Out:
#                  ShippingDelay
# Category
# Furniture             4.000000
# Office Supplies       3.975028
# Technology            4.125410

# %% [markdown]
# ### Challenge problem:
# **In what months and Categories were Sales Targets Exceeded?**
#
# ---
#
# This may require a considerable amount of data processing.

# %%
# A:
